# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **SHAGUN DEOGHAREKAR**, I am a Student

# %% [markdown]
# *I am interested in Data Science because I want to experience the evergrowing feild Artificial Intiligence and Machine Learning*

# %% [markdown]
# ## So here we will be writing a function that will acept two parameters and return their product as an output

# %%
def product(a,b):
    return a*b

product(5,10)
# Out:
# 50

# %% [markdown]
# 1. Python
# 2. C++
# 3. Java

# %% [markdown]
# - Python
# - Angular
# - React

# %% [markdown]
# ![vettel.jpg](attachment:vettel.jpg)
